# %%
# Importing the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
amns_data = pd.read_csv("AMNS_India_Trade_Data.csv")

# %%
# Display the first few rows
amns_data.head()
# Out:
#           DATE IMPORTER NAME  \
# 0  29-Aug-2020    AMNS India
# 1  19-Aug-2020    AMNS India
# 2  19-Aug-2020    AMNS India
# 3  19-Aug-2020    AMNS India
# 4  19-Aug-2020    AMNS India
#
#                                     IMPORTER ADDRESS SUPPLIER NAME  \
# 0  Plot No-89, Said Grand Center, (7thFloor), Sec...    AMNS India
# 1  7 No Rajar Goli, Sylhet; KotwaliPS; Sylhet- 31...    AMNS India
# 2  Ridge Ahmed Square, 50/1 NayaPaltan, Inner Cir...    AMNS India
# 3  7 No Rajar Goli, Sylhet; KotwaliPS; Sylhet- 31...    AMNS India
# 4  Plot # 34. H.M. Plaza, Road # 02.,Sector # 03,...    AMNS India
#
#                                     SUPPLIER ADDRESS DECLARANT NAME  \
# 0                                        NETHERLANDS     AMNS India
# 1  UNIT 13 BRENTWOOD BUSINESS PARK, BENONI, SOUTH...     AMNS India
# 2                                             TAIWAN     AMNS India
# 3  UNIT 13 BRENTWOOD BUSINESS PARK , BENONI SOUTH...     AMNS India
# ...

# %%
# Describe the basic information about the dataset
amns_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATE                      20 non-null     object
#  1   IMPORTER NAME             20 non-null     object
#  2   IMPORTER ADDRESS          20 non-null     object
#  3   SUPPLIER NAME             20 non-null     object
#  4   SUPPLIER ADDRESS          20 non-null     object
#  5   DECLARANT NAME            20 non-null     object
#  6   DECLARANT ADDRESS         20 non-null     object
#  7   EXPORT COUNTRY            20 non-null     object
#  8   ORIGIN COUNTRY            20 non-null     object
#  9   HS CODE                   20 non-null     int64
#  10  PRODUCT DESCRIPTION       20 non-null     object
#  11  PACKAGE UNIT NAME         20 non-null     object
#  12  UNIT                      20 non-null     object
# ...

# %%
# Shape of the data
amns_data.shape
# Out:
# (20, 40)

# %%
print(amns_data.dtypes)
# Out:
# DATE                         object
# IMPORTER NAME                object
# IMPORTER ADDRESS             object
# SUPPLIER NAME                object
# SUPPLIER ADDRESS             object
# DECLARANT NAME               object
# DECLARANT ADDRESS            object
# EXPORT COUNTRY               object
# ORIGIN COUNTRY               object
# HS CODE                       int64
# PRODUCT DESCRIPTION          object
# PACKAGE UNIT NAME            object
# UNIT                         object
# TOTAL PACKAGES                int64
# QUANTITY                      int64
# ITEMS                         int64
# ITEM NO                       int64
# NO OF PACKAGES ITEM           int64
# GROSS WEIGHT KG             float64
# NET WEIGHT KG               float64
# DECLARED UNIT PRICE FC      float64
# ASSESSABLE UNIT PRICE FC    float64
# ITEM PRICE FC               float64
# TOTAL INVOICE VALUE FC      float64
# CURRENCY                     object
# TOTAL VALUE BDT             float64
# ...

# %%
# Check for missing values
amns_data.isnull().sum()
# Out:
# DATE                        0
# IMPORTER NAME               0
# IMPORTER ADDRESS            0
# SUPPLIER NAME               0
# SUPPLIER ADDRESS            0
# DECLARANT NAME              0
# DECLARANT ADDRESS           0
# EXPORT COUNTRY              0
# ORIGIN COUNTRY              0
# HS CODE                     0
# PRODUCT DESCRIPTION         0
# PACKAGE UNIT NAME           0
# UNIT                        0
# TOTAL PACKAGES              0
# QUANTITY                    0
# ITEMS                       0
# ITEM NO                     0
# NO OF PACKAGES ITEM         0
# GROSS WEIGHT KG             0
# NET WEIGHT KG               0
# DECLARED UNIT PRICE FC      0
# ASSESSABLE UNIT PRICE FC    0
# ITEM PRICE FC               0
# TOTAL INVOICE VALUE FC      0
# CURRENCY                    0
# TOTAL VALUE BDT             0
# TOTAL VALUE USD             0
# TOTAL TAX BDT               0
# TOTAL DECLARATION           0
# TOTAL OTHER COSTS           0
# EXCHANGE RATE               0
# ...

# %%
# Check for duplicates
amns_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data = {
    "Date": ["05-02-2020", "12-02-2020", "19-02-2020", "26-02-2020", "05-03-2020"],
    "Weekly_Sales": [50000, 52000, 48000, 53000, 51000],
}

# %%
# Convert to DataFrame
amns_data = pd.DataFrame(data)

# %%
# Ensure 'Date' column exists before converting
if 'Date' in amns_data.columns:
    amns_data['Date'] = pd.to_datetime(amns_data['Date'], format="%d-%m-%Y", errors='coerce')
else:
    print("Error: 'Date' column not found!")

# %%
# Display the DataFrame
print(amns_data)
# Out:
#         Date  Weekly_Sales
# 0 2020-02-05         50000
# 1 2020-02-12         52000
# 2 2020-02-19         48000
# 3 2020-02-26         53000
# 4 2020-03-05         51000

# %%
# Ensure 'Date' conversion was successful before extracting features
if amns_data['Date'].isna().all():
    print("Error: All values in 'Date' column are NaT (invalid format).")
else:
    # Extract Year, Month, and Week
    amns_data['Year'] = amns_data['Date'].dt.year
    amns_data['Month'] = amns_data['Date'].dt.month
    amns_data['Week'] = amns_data['Date'].dt.isocalendar().week

    # Calculate week-over-week sales changes
    amns_data['Sales_Difference'] = amns_data['Weekly_Sales'].diff()

    # Calculate a rolling average for sales (4-week window)
    amns_data['Rolling_Sales_Avg'] = amns_data['Weekly_Sales'].rolling(window=4, min_periods=1).mean()
plt.figure('Date,Week,Month,Year')    

amns_data.head()
# Out:
#         Date  Weekly_Sales  Year  Month  Week  Sales_Difference  \
# 0 2020-02-05         50000  2020      2     6               NaN
# 1 2020-02-12         52000  2020      2     7            2000.0
# 2 2020-02-19         48000  2020      2     8           -4000.0
# 3 2020-02-26         53000  2020      2     9            5000.0
# 4 2020-03-05         51000  2020      3    10           -2000.0
#
#    Rolling_Sales_Avg
# 0            50000.0
# 1            51000.0
# 2            50000.0
# 3            50750.0
# 4            51000.0

# %%
plt.figure(figsize=(14, 7))

# %%
plt.title("Total Weekly Sales Trend Over Time", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Total Weekly Sales Trend Over Time')

# %%
plt.xlabel("Date", fontsize=12)
plt.ylabel("Weekly Sales", fontsize=12)
# Out:
# Text(0, 0.5, 'Weekly Sales')

# %%
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7084\598546866.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
data = {
    "Year": [2020, 2021, 2022, 2023, 2024],
    "Month": [1, 2, 3, 4, 5],
    "Week": [5, 10, 15, 20, 25],
    "Temperature": [30, 32, 28, 35, 31],
    "Fuel_Price": [2.5, 2.6, 2.7, 2.8, 2.9],
    "CPI": [200, 205, 210, 215, 220],
    "Unemployment": [6.0, 6.2, 6.1, 6.3, 6.4],
    "Weekly_Sales": [50000, 52000, 48000, 53000, 51000],
}

# %%
df = pd.DataFrame(data)

# %%
# Define Features and Target
features = df[["Year", "Month", "Week", "Temperature", "Fuel_Price", "CPI", "Unemployment"]]
target = df["Weekly_Sales"]

# %%
# Handle Missing Values (if any)
features.fillna(features.mean(), inplace=True)
target.fillna(target.mean(), inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7084\2172349605.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features.fillna(features.mean(), inplace=True)

# %%
from sklearn.ensemble import RandomForestRegressor

# Train a Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Extract feature importances
feature_importances = pd.Series(rf_model.feature_importances_, index=features.columns).sort_values(ascending=False)

# %%
# Plot feature importances
plt.figure(figsize=(10, 5))
sns.barplot(x=feature_importances.values, y=feature_importances.index, palette="Blues_r")
plt.xlabel("Feature Importance Score")
plt.ylabel("Feature")
plt.title("Feature Importance for AMNS India Trade Value Prediction")
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5232\3972921040.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_importances.values, y=feature_importances.index, palette="Blues_r")

# %%
# Predictions
y_pred = rf_model.predict(X_test)

# %%
# Evaluate the Model
mae = mean_absolute_error(y_test, y_pred)

print(f"Model Evaluation Complete:\nMAE: {mae:.2f}")
# Out:
# Model Evaluation Complete:
# MAE: 2120.00

# %%
# Plot feature importances
plt.figure(figsize=(10, 5))
sns.barplot(x=feature_importances.values, y=feature_importances.index, palette="Blues_r")
plt.xlabel("Feature Importance Score")
plt.ylabel("Feature")
plt.title("Feature Importance for Trade Value Prediction")
plt.show()

feature_importances
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5232\4228691964.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_importances.values, y=feature_importances.index, palette="Blues_r")
# Temperature     0.332078
# Month           0.146070
# Unemployment    0.128827
# Year            0.118974
# CPI             0.108521
# Week            0.089140
# Fuel_Price      0.076390
# dtype: float64

# %%
# Predictions
y_pred = rf_model.predict(X_test)

# %%
# Extract feature importances
feature_importances = pd.Series(rf_model.feature_importances_, index=features.columns).sort_values(ascending=False)

# %%
product_sales_variability = amns_data.groupby('Month')['Weekly_Sales'].std().sort_values(ascending=False)
print(product_sales_variability)
# Out:
# Month
# 2    2217.355783
# 3            NaN
# Name: Weekly_Sales, dtype: float64

# %%
# Top 10 products with the highest sales variability
high_variability_products = product_sales_variability.head(10)
print(high_variability_products)
# Out:
# Month
# 2    2217.355783
# 3            NaN
# Name: Weekly_Sales, dtype: float64

# %%
# Visualization
high_variability_products.plot(kind='bar', figsize=(10, 6), color='yellow', edgecolor='black')
plt.title('Top 10 Products with High Sales Variability', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Standard Deviation of Sales', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(amns_data.corr(), annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("Correlation Analysis")
plt.show()

# %%
# Train-Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Train Linear Regression Model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Evaluate the Model
from sklearn.metrics import mean_absolute_error
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)

print(f"MAE: {mae}")
# Out:
# MAE: 352.9411764705874

# %%
# Visual Predictions
# Visualize Predicted vs Actual Sales
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.6, color="blue", label="Predicted vs Actual")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color="yellow", linestyle="--", label="Perfect Prediction")
plt.title("Predicted vs Actual Sales", fontsize=16)
plt.xlabel("Actual Sales", fontsize=12)
plt.ylabel("Predicted Sales", fontsize=12)
plt.legend()
plt.show()

# %%
# Describe the dataset to get summary statistics
amns_data_description = amns_data.describe()

# %%
# Plot the description as a table image
fig, ax = plt.subplots(figsize=(10, 4))
ax.axis('tight')
ax.axis('off')
ax.table(cellText=amns_data_description.round(2).values, 
         colLabels=amns_data_description.columns, 
         rowLabels=amns_data_description.index, 
         cellLoc='center', loc='center')
